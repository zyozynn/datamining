# %%
# Program Aplikasi Gaji Karyawan by Siti Ainun Rodhiyah
# TI-2B - 44.33.21.1.24

print("===============================================================")
print("                   APLIKASI GAJI KARYAWAN")
print("===============================================================")
print("| List Pekerjaan |")
print("| 1. Data Scientist |")
print("| 2. Web Developer |")
print("| 3. Data Analyst |")
print("| 4. Software Development Engineer |")
print("| 5. Computer Hardware Engineer |")
print("| 6. Exit |")
print("===============================================================")
pilih=int(input("Masukan Pilihan Anda : "))
if pilih == 1:
    print('Gaji Karyawan DataScientist')   
    nama = str(input("Masukan Nama : "))
    gol = input("Golongan Kerja : ")
    jam = int(input("Masukan jam Kerja : "))
    print ("1. SMA \n2. D1 \n3. D3 \n4. S1")
    golpen=input("Masukan Pendidikan \t: ")
    gaji = 300000
#     gaji=8000000
#     tunjangan=0.50*gaji
#     PPN=0.1*gaji
#     total=(gaji+tunjangan)-PPN
#     print("===========================")
#     print("Gaji Pokok = ",gaji)
#     print("Tunjangan = ",tunjangan)
#     print("Pajak Penghasilan = ",PPN)
#     print("Total Gaji Datascientist = ",total)
elif pilih == 2:
    print('Gaji Karyawan Programmer')
    gaji=6700000
    tunjangan=0.30*gaji
    PPN=0.3*gaji
    total=(gaji+tunjangan)-PPN
    print("===========================")
    print("Gaji Pokok = ",gaji)
    print("Tunjangan = ",tunjangan)
    print("Pajak Penghasilan = ",PPN)
    print("Total Gaji Programmer = ",total)
elif pilih == 3:
    print('Data Analyst')
    gaji=5000000
    tunjangan=0.40*gaji
    PPN=0.1*gaji
    total=(gaji+tunjangan)-PPN
    print("===========================")
    print("Gaji Pokok = ",gaji)
    print("Tunjangan = ",tunjangan)
    print("Pajak Penghasilan = ",PPN)
    print("Total Gaji Data Analyst = ",total)
elif pilih == 4:
    print('Android Developer')
    gaji=5500000
    tunjangan=0.30*gaji
    PPN=0.1*gaji
    total=(gaji+tunjangan)-PPN
    print("===========================")
    print("Gaji Pokok = ",gaji)
    print("Tunjangan = ",tunjangan)
    print("Pajak Penghasilan = ",PPN)
    print(" Total Gaji Android Developer = ",total)
elif pilih == 5:
    print('Terima Kasih Telah memakai Progam')
else:
    print('Maaf, format nilai tidak sesuai')
# Out:
# ...
#                    APLIKASI GAJI KARYAWAN
# ...
# | List Pekerjaan |
# | 1. DataScientist |
# | 2. Programmer |
# | 3. Data Analyst |
# | 4. Android Developer |
# | 5. Exit |
# ...
# Masukan Pilihan Anda : 1
# Gaji Karyawan DataScientist
# ...
# Gaji Pokok =  8000000
# Tunjangan =  4000000.0
# Pajak Penghasilan =  800000.0
# Total Gaji Datascientist =  11200000.0
